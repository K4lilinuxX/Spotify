# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("artistas_spotify.csv", encoding="latin-1")

# %%
#Quita el límite máximo de columnas a mostrar
pd.set_option('display.max_columns', None)

# %%
df.head(20)
# Out:
#                                     Track  \
# 0                     MILLION DOLLAR BABY
# 1                             Not Like Us
# 2              i like the way you kiss me
# 3                                 Flowers
# 4                                 Houdini
# 5                             Lovin On Me
# 6                        Beautiful Things
# 7                               Gata Only
# 8                    Danza Kuduro - Cover
# 9              BAND4BAND (feat. Lil Baby)
# 10  I Had Some Help (feat. Morgan Wallen)
# 11                               The Door
# 12                                  LUNCH
# 13                              Like That
# 14                         bathroom floor
# 15                                   LALA
# 16          Fortnight (feat. Post Malone)
# 17                                 greedy
# 18                                   BLUE
# 19                              As It Was
#
#                                       Album Name          Artist Release Date  \
# 0                   Million Dollar Baby - Single   Tommy Richman    4/26/2024
# 1                                    Not Like Us  Kendrick Lamar     5/4/2024
# 2                     I like the way you kiss me         Artemas    3/19/2024
# 3                               Flowers - Single     Miley Cyrus    1/12/2023
# 4                                        Houdini          Eminem    5/31/2024
# 5                                    Lovin On Me     Jack Harlow   11/10/2023
# 6                               Beautiful Things    Benson Boone    1/18/2024
# 7                                      Gata Only      FloyyMenor     2/2/2024
# 8   ýýýýýýýýýýýýýýýýýýýýý - ýýýýýýýýýýýýýýýýýý -   MUSIC LAB JPN     6/9/2024
# 9                     BAND4BAND (feat. Lil Baby)     Central Cee    5/23/2024
# 10                               I Had Some Help     Post Malone    5/10/2024
# 11                                      The Door     Teddy Swims    6/14/2024
# 12                          HIT ME HARD AND SOFT   Billie Eilish    5/17/2024
# 13                            WE DON'T TRUST YOU          Future    3/22/2024
# 14                                bathroom floor  Kids With Buns    10/7/2022
# 15                                 LALA - Single     Myke Towers    3/22/2023
# 16                 THE TORTURED POETS DEPARTMENT    Taylor Swift    4/18/2024
# 17                                        greedy      Tate McRae    9/14/2023
# 18                          HIT ME HARD AND SOFT   Billie Eilish    5/17/2024
# 19                                     As It Was    Harry Styles    3/31/2022
#
#             ISRC All Time Rank  Track Score Spotify Streams  \
# 0   QM24S2402528             1        725.4     390,470,936
# 1   USUG12400910             2        545.9     323,703,884
# 2   QZJ842400387             3        538.4     601,309,283
# 3   USSM12209777             4        444.9   2,031,280,633
# 4   USUG12403398             5        423.3     107,034,922
# 5   USAT22311371             6        410.1     670,665,438
# 6   USWB12307016             7        407.2     900,158,751
# 7   QZL382406049             8        375.8     675,079,153
# 8   TCJPA2463708             9        355.7   1,653,018,119
# 9   USSM12404354            10        330.6      90,676,573
# 10  USUM72404990            11        322.1     250,080,413
# 11  USWB12402486            12        320.2     111,155,129
# 12  USUM72401991            13        316.3     221,636,195
# 13  USSM12402041            14        308.2     355,186,436
# 14  NLC242100307            15        301.6         297,185
# 15  USWL12300002            16        299.9     925,655,569
# 16  USUG12401028            17        297.6     395,433,400
# 17  USRC12301932            18        293.7   1,258,569,694
# 18  USUM72401996            19        292.6      91,272,461
# 19  USSM12200612            20        292.0   3,301,814,535
#
#    Spotify Playlist Count Spotify Playlist Reach  Spotify Popularity  \
# 0                  30,716            196,631,588                92.0
# 1                  28,113            174,597,137                92.0
# 2                  54,331            211,607,669                92.0
# 3                 269,802            136,569,078                85.0
# 4                   7,223            151,469,874                88.0
# 5                 105,892            175,421,034                83.0
# 6                  73,118            201,585,714                86.0
# 7                  40,094            211,236,940                92.0
# 8                       1                     15                 NaN
# 9                  10,400            184,199,419                86.0
# 10                 16,219            168,766,158                91.0
# 11                      2                263,767                 NaN
# 12                 13,800            197,280,692                92.0
# 13                 43,025            108,168,634                88.0
# 14                    277                 24,445                12.0
# 15                103,605             79,944,921                79.0
# 16                 12,784            177,932,568                89.0
# 17                105,218            198,845,580                87.0
# 18                  6,499             52,287,548                86.0
# 19                407,119            169,783,402                87.0
#
#     YouTube Views YouTube Likes TikTok Posts   TikTok Likes    TikTok Views  \
# 0      84,274,754     1,713,126    5,767,700    651,565,900   5,332,281,936
# 1     116,347,040     3,486,739      674,700     35,223,547     208,339,025
# 2     122,599,116     2,228,730    3,025,400    275,154,237   3,369,120,610
# 3   1,096,100,899    10,629,796    7,189,811  1,078,757,968  14,603,725,994
# 4      77,373,957     3,670,188       16,400            NaN             NaN
# 5     131,148,091     1,392,593    4,202,367    214,943,489   2,938,686,633
# 6     308,723,145     4,120,760          NaN     29,584,940     534,915,313
# 7     228,382,568     1,439,495    3,500,000    338,546,668   3,804,584,163
# 8             NaN           NaN          NaN            NaN             NaN
# 9      32,735,244       988,682      325,800    121,574,500     974,656,200
# 10     32,229,063       550,191          NaN        184,500       2,100,000
# 11            NaN           NaN          NaN            NaN             NaN
# 12     40,022,524     1,307,290      195,300     45,889,000     360,017,000
# 13     98,081,493     1,456,177          NaN            NaN             NaN
# 14  6,736,502,312    16,785,489            3          1,088          22,234
# 15    934,302,031     4,294,166   11,054,500    521,725,116   7,499,234,052
# 16    104,673,836     2,484,083      139,300     25,348,800     207,317,000
# 17    141,646,818     1,514,837    2,294,429    419,319,161   5,456,156,211
# 18     16,038,053       569,377      941,900    119,740,900   1,225,345,800
# 19    800,899,315     9,101,589    2,755,903  1,633,970,617  15,405,881,843
#
#    YouTube Playlist Reach  Apple Music Playlist Count AirPlay Spins  \
# 0             150,597,040                       210.0        40,975
# 1             156,380,351                       188.0        40,778
# 2             373,784,955                       190.0        74,333
# 3           3,351,188,582                       394.0     1,474,799
# 4             112,763,851                       182.0        12,185
# 5           2,867,222,632                       138.0       522,042
# 6           4,601,579,812                       280.0       383,478
# 7           2,112,581,620                       160.0        17,221
# 8                     NaN                         NaN           NaN
# 9             174,706,874                       191.0         3,823
# 10            327,130,768                       157.0        62,312
# 11                    NaN                         NaN           NaN
# 12            342,107,131                       244.0        41,344
# 13            174,491,415                       153.0        90,237
# 14                    NaN                         1.0         1,057
# 15          2,042,145,659                        94.0        92,231
# 16            268,893,710                       221.0       129,968
# 17          2,667,285,437                       207.0       667,329
# 18              5,839,168                        76.0           181
# 19          7,289,707,052                       455.0     1,777,811
#
#    SiriusXM Spins  Deezer Playlist Count Deezer Playlist Reach  \
# 0             684                   62.0            17,598,718
# 1               3                   67.0            10,422,430
# 2             536                  136.0            36,321,847
# 3           2,182                  264.0            24,684,248
# 4               1                   82.0            17,660,624
# 5           4,654                   86.0            17,167,254
# 6             429                  168.0            48,197,850
# 7              30                   87.0            33,245,595
# 8             NaN                    NaN                   NaN
# 9             117                   78.0            10,800,098
# 10             71                   60.0            12,009,073
# 11            NaN                    NaN                   NaN
# 12             45                  138.0            38,243,636
# 13              3                   55.0             3,001,826
# 14            NaN                    NaN                   NaN
# 15            228                   60.0             5,633,435
# 16              3                   99.0            37,988,531
# 17          3,310                  188.0            21,788,568
# 18              1                   24.0             5,054,005
# 19          4,909                  330.0            12,907,852
#
#     Amazon Playlist Count Pandora Streams Pandora Track Stations  \
# 0                   114.0      18,004,655                 22,931
# 1                   111.0       7,780,028                 28,444
# 2                   172.0       5,022,621                  5,639
# 3                   210.0     190,260,277                203,384
# 4                   105.0       4,493,884                  7,006
# 5                   152.0     138,529,362                 50,982
# 6                   154.0      65,447,476                 57,372
# 7                    53.0       3,372,428                  5,762
# 8                     NaN             NaN                    NaN
# 9                    92.0       1,005,626                    842
# 10                  114.0      23,155,471                 21,172
# 11                    2.0             NaN                    NaN
# 12                  163.0       1,354,692                  1,219
# 13                  109.0      26,252,264                 18,364
# 14                    NaN             NaN                    NaN
# 15                   83.0      12,171,026                 13,242
# 16                  134.0       9,961,769                 13,437
# 17                  150.0      44,850,379                 12,270
# 18                   33.0         283,089                    162
# 19                  189.0     132,624,772                 79,909
#
#    Soundcloud Streams Shazam Counts  TIDAL Popularity  Explicit Track
# 0           4,818,457     2,669,262               NaN               0
# 1           6,623,075     1,118,279               NaN               1
# 2           7,208,651     5,285,340               NaN               0
# 3                 NaN    11,822,942               NaN               0
# 4             207,179       457,017               NaN               1
# 5           9,438,601     4,517,131               NaN               1
# 6                 NaN     9,990,302               NaN               0
# 7                 NaN     6,063,523               NaN               1
# 8                 NaN           NaN               NaN               1
# 9           3,679,709       666,302               NaN               1
# 10          1,594,605       963,413               NaN               1
# 11                NaN           NaN               NaN               1
# 12          1,313,357       450,344               NaN               0
# 13         12,038,034     1,963,314               NaN               1
# 14                NaN         3,288               NaN               0
# 15            871,978     2,765,808               NaN               1
# 16            377,734     1,210,029               NaN               0
# 17                NaN     6,973,652               NaN               1
# 18            975,891       257,661               NaN               0
# 19                NaN    14,967,379               NaN               0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Track                       4600 non-null   str
#  1   Album Name                  4600 non-null   str
#  2   Artist                      4595 non-null   str
#  3   Release Date                4600 non-null   str
#  4   ISRC                        4600 non-null   str
#  5   All Time Rank               4600 non-null   str
#  6   Track Score                 4600 non-null   float64
#  7   Spotify Streams             4487 non-null   str
#  8   Spotify Playlist Count      4530 non-null   str
#  9   Spotify Playlist Reach      4528 non-null   str
#  10  Spotify Popularity          3796 non-null   float64
#  11  YouTube Views               4292 non-null   str
#  12  YouTube Likes               4285 non-null   str
#  13  TikTok Posts                3427 non-null   str
#  14  TikTok Likes                3620 non-null   str
#  15  TikTok Views                3619 non-null   str
#  16  YouTube Playlist Reach      3591 non-null   str
#  17  Apple Music Playlist Count  4039 non-null   float64
#  18  AirPlay Spins               4102 non-null   str
#  19  SiriusXM Spins              2477 non-null   str
#  20  Deezer Playlist Count       3679 non-null   float64
#  21  Deezer Playlist Reach       3672 non-null   str
#  22  Amazon Playlist Count       3545 non-null   float64
#  23  Pandora Streams             3494 non-null   str
#  24  Pandora Track Stations      3332 non-null   str
#  25  Soundcloud Streams          1267 non-null   str
#  26  Shazam Counts               4023 non-null   str
#  27  TIDAL Popularity            0 non-null      float64
#  28  Explicit Track              4600 non-null   int64
# dtypes: float64(6), int64(1), str(22)
# memory usage: 1.0 MB

# %%
# Verificamos si hay datos nulos, si hay :(
df.isna().sum()
# Out:
# Track                            0
# Album Name                       0
# Artist                           5
# Release Date                     0
# ISRC                             0
# All Time Rank                    0
# Track Score                      0
# Spotify Streams                113
# Spotify Playlist Count          70
# Spotify Playlist Reach          72
# Spotify Popularity             804
# YouTube Views                  308
# YouTube Likes                  315
# TikTok Posts                  1173
# TikTok Likes                   980
# TikTok Views                   981
# YouTube Playlist Reach        1009
# Apple Music Playlist Count     561
# AirPlay Spins                  498
# SiriusXM Spins                2123
# Deezer Playlist Count          921
# Deezer Playlist Reach          928
# Amazon Playlist Count         1055
# Pandora Streams               1106
# Pandora Track Stations        1268
# Soundcloud Streams            3333
# Shazam Counts                  577
# TIDAL Popularity              4600
# Explicit Track                   0
# dtype: int64

# %%
list(df.columns)
# Out:
# ['Track',
#  'Album Name',
#  'Artist',
#  'Release Date',
#  'ISRC',
#  'All Time Rank',
#  'Track Score',
#  'Spotify Streams',
#  'Spotify Playlist Count',
#  'Spotify Playlist Reach',
#  'Spotify Popularity',
#  'YouTube Views',
#  'YouTube Likes',
#  'TikTok Posts',
#  'TikTok Likes',
#  'TikTok Views',
#  'YouTube Playlist Reach',
#  'Apple Music Playlist Count',
#  'AirPlay Spins',
#  'SiriusXM Spins',
#  'Deezer Playlist Count',
#  'Deezer Playlist Reach',
#  'Amazon Playlist Count',
#  'Pandora Streams',
#  'Pandora Track Stations',
#  'Soundcloud Streams',
#  'Shazam Counts',
#  'TIDAL Popularity',
#  'Explicit Track']

# %% [markdown]
# ## ¿Cuáles son los artistas que mas canciones tienen en el Data Frame?

# %%
# ----- Análisis de la cantidad de artistas y los mas "famosos" del set de datos-----

# Vemos la cantidad de artistas que hay
len(df["Artist"].value_counts()) # Hay 1999 artistas distintos

# Top 25 artistas que mas canciones tienen en el set de datos
top_25_artistas = df["Artist"].value_counts().sort_values(ascending=False).head(25)

# Gráfica
plt.figure(figsize=(12,6))
plt.title("Top 25 artistas que mas canciones tienen en el set de datos")
barras = sns.barplot(x=top_25_artistas.index,
                     y=top_25_artistas.values,
                     hue=top_25_artistas.index,
                     palette="Blues")
# Agregamos el número de veces que aparece el artista en el set de datos
for contenedores in barras.containers:
    barras.bar_label(contenedores,
                     fmt='%.0f')
    
# Ajustamos los 'labels' de los ejes X, Y
plt.xlabel("Nombre del artista")
plt.ylabel("Cantidad de canciones")

# Ajustamos la rotación de los nombres de los artistas para que no se vean amontonados
plt.xticks(rotation=45,
           ha="right")

# Ajustamos el 'grid' de la gráfica para que se vea visualmente superior
plt.grid(axis="y",
         linestyle="--",
         alpha=0.6)

# Mostramos la gráfica en pantalla
plt.show()

# %%
import requests
import time

# Definimos la API Key de Last.fm (ya tengo creada mi cuenta)
API_KEY = "d638622c0f55ebf99d24d8febd412851"
url_base = "http://ws.audioscrobbler.com/2.0/"
diccionario_tags = {}

# Obtenemos los artistas únicos desde mi DataFrame 'df' ya existente en memoria
artistas_unicos = df['Artist'].unique()

print(f"Iniciando extracción para {len(artistas_unicos)} artistas...")

for artista in artistas_unicos:
    parametros = {
        'method': 'artist.gettoptags',
        'artist': artista,
        'api_key': API_KEY,
        'format': 'json',
        'autocorrect': 1
    }
    
    try:
        respuesta = requests.get(url_base, params=parametros)
        datos = respuesta.json()
        
        if 'toptags' in datos and 'tag' in datos['toptags']:
            # Tomamos los 5 tags más relevantes asignados por la comunidad
            lista_tags = [tag['name'] for tag in datos['toptags']['tag'][:5]]
            diccionario_tags[artista] = ", ".join(lista_tags).lower()
        else:
            diccionario_tags[artista] = "no encontrado"
            
    except Exception as e:
        diccionario_tags[artista] = "error"
    
    # Pausa de 200ms para mantener las peticiones seguras y estables
    time.sleep(0.2)

print("Extracción completada!")

# Mapeamos las etiquetas directamente a la nueva columna del DataFrame
df['Generos'] = df['Artist'].map(diccionario_tags)

# Creamos las máscaras booleanas puras para la clasificación (evitando loc/iloc)
es_latino = df['Generos'].str.contains('latin|reggaeton|mexicano|urbano|español|ranchera|corrido|salsa|bachata', case=False, na=False)
es_anglo = df['Generos'].str.contains('pop|rap|hip hop|rock|country|uk|english|indie', case=False, na=False) & ~es_latino

# Usamos np.select para asignar los grupos
df['Grupo'] = np.select([es_latino, es_anglo], ['Latino', 'Anglosajón'], default='Otro')

# Filtramos el set de datos final para remover los que no entran en la comparación directa
df_analisis = df[df['Grupo'] != 'Otro'].copy()

# Verificamos el resultado en consola
print("Muestra de la clasificación final:")
print(df_analisis[['Artist', 'Generos', 'Grupo']].head(10))
# Out:
# Iniciando extracción para 2000 artistas...
# Extracción completada!
# Muestra de la clasificación final:
#             Artist                                            Generos  \
# 0    Tommy Richman                  rnb, rap, funk, hip-hop, virginia
# 1   Kendrick Lamar         hip-hop, rap, west coast, hip hop, compton
# 2          Artemas                 pop, british, rnb, indie, dark pop
# 3      Miley Cyrus  pop, female vocalists, dance, disney, guilty p...
# 4           Eminem                 rap, hip-hop, hip hop, eminem, pop
# 5      Jack Harlow               rap, hip-hop, trap, hip hop, pop rap
# 6     Benson Boone  pop, pop rock, rock, my top songs, singer-song...
# 7       FloyyMenor  chile, reggaeton, reggaeton chileno, malianteo...
# 9      Central Cee             rap, drill, hip-hop, hip hop, uk drill
# 10     Post Malone                 hip-hop, rap, trap, cloud rap, pop
#
#          Grupo
# 0   Anglosajón
# 1   Anglosajón
# 2   Anglosajón
# 3   Anglosajón
# 4   Anglosajón
# 5   Anglosajón
# 6   Anglosajón
# 7       Latino
# 9   Anglosajón
# 10  Anglosajón

# %% [markdown]
# ## ¿Cuál es la cantidad de artistas anglosajones y latinos que hay?

# %% [markdown]
# Agregamos el `drop_duplicates(subset=['Artist', 'Grupo'])`. Esto le dice a Pandas: "Si ves a Eminem 10 veces en la columna 'Artist', quédate solo con la primera y borra las otras 9".

# %%
# Usamos el df_analisis para que únicamente salgan los artistas que la API clasificó como Anglosajón y Latino
# Creamos un DataFrame sin duplicados, quedándonos solo con un registro por artista
df_artistas_unicos = df_analisis.drop_duplicates(subset=['Artist', 'Grupo'])

# Contamos la cantidad real de artistas por grupo
grupo_artistas = df_artistas_unicos["Grupo"].value_counts()

# Graficamos
plt.figure(figsize=(12, 6))
plt.title("Cantidad de artistas anglosajones y latinos")
barras = sns.barplot(x=grupo_artistas.index,
                     y=grupo_artistas.values,
                     hue=grupo_artistas.index,
                     palette="Blues"
)
# Agregamos el número de artistas anglosajones y latinos que hay 
for contenedores in barras.containers:
    barras.bar_label(contenedores,
                     fmt='%.0f')

plt.xlabel("Grupo del artista")
plt.ylabel("Cantidad de artistas")
plt.grid(axis="y",
         linestyle="--",
         alpha=0.6)
plt.show()

# %% [markdown]
# ## ¿Cuál es el grupo de artistas que tiene mas popularidad en Spotify?

# %%
# Agrupamos la popularidad en Spotify por grupo
popularidad_grupos = df_analisis.groupby("Grupo")["Spotify Popularity"].mean()

# Graficamos
plt.figure(figsize=(12,6))
plt.title("Popularidad en Spotify por grupo de artistas")
barras = sns.barplot(x=popularidad_grupos.index,
                     y=popularidad_grupos.values,
                     hue=popularidad_grupos.index,
                     palette="magma")
# Agregamos el promedio de popularidad en Spotify por cada grupo (Anglosajones y Latinos)
for contenedores in barras.containers:
    barras.bar_label(contenedores,
                     fmt='%.2f')
plt.xlabel("Grupo del artista")
plt.ylabel("Promedio de popularidad en Spotify")
plt.grid(axis="y",
         linestyle="-",
         alpha=0.6)
plt.show()

# %% [markdown]
# ## Mi explicación acerca de la popularidad promedio en Spotify de los artistas por grupo
# En la gráfica se puede observar un fenómeno muy interesante y muy alentador para la comunidad latina, ya que los artistas latinos superan (al menos en Spotify) en popularidad a los anglosajones, a pesar de que en la gráfica de barras que lleva por nombre `"Cantidad de artistas anglosajones y latinos"` se puede apreciar que la cantidad artistas anglosajones es de 1098, contra los 166 latinos. Es decir que los anglosajones son casi **7 veces mas numerosos** con respecto a los latinos. Lo cual es muy impresionante, ya que los artistas latinos a pesar de ser 7 veces mas reducidos en numero superan en popularidad a artistas que los superan casi 7 veces.
#
# Y no es de extrañar ya que en el año 2024 los 10 artistas latinos mas escuchados en Spotify fueron:
# 1. Bad Bunny 🇵🇷
# 2. Peso Pluma 🇲🇽
# 3. Feid 🇨🇴
# 4. Karol G 🇨🇴
# 5. Junior H 🇲🇽
# 6. Rauw Alejandro 🇵🇷
# 7. Natanael Cano 🇲🇽
# 8. Fuerza Regida 🇲🇽
# 9. Myke Towers 🇵🇷
# 10. Anuel AA 🇵🇷
#
# **Datos curiosos 👀**
# * Bad Bunny fue el artista latino más escuchado del mundo en Spotify por quinto año consecutivo.
# * Solo tres artistas latinos entraron al Top 10 global de Spotify 2024: Bad Bunny (#3), Peso Pluma (#7) y Feid (#10).
# * La música mexicana fue el género latino con mayor crecimiento en Spotify durante 2024.
# * México colocó cuatro artistas dentro del Top 10 latino: Peso Pluma, Junior H, Natanael Cano y Fuerza Regida

# %% [markdown]
# ## ¿Cuáles son las cifras de oyentes anuales de los artistas latinos mas escuchados en Spotify del 2024?

# %%
# Diccionarios de los 10 artistas latinos mas escuchados del 2024 con la cantidad de oyentes anuales a partir de su debut en la música

spotify_bad_bunny = {
    2016: 500_000_000,
    2017: 1_000_000_000,
    2018: 3_000_000_000,
    2019: 5_000_000_000,
    2020: 8_300_000_000,
    2021: 9_100_000_000,
    2022: 18_500_000_000,
    2023: 15_000_000_000,
    2024: 12_000_000_000,
    2025: 19_800_000_000
}

spotify_peso_pluma = {
    2019: 100_000_000,
    2020: 300_000_000,
    2021: 800_000_000,
    2022: 2_500_000_000,
    2023: 11_000_000_000,
    2024: 9_500_000_000,
    2025: 8_500_000_000
}

spotify_feid = {
    2015: 50_000_000,
    2016: 100_000_000,
    2017: 250_000_000,
    2018: 500_000_000,
    2019: 1_000_000_000,
    2020: 2_000_000_000,
    2021: 3_500_000_000,
    2022: 6_000_000_000,
    2023: 9_000_000_000,
    2024: 10_500_000_000,
    2025: 9_500_000_000
}

spotify_karol_g = {
    2013: 50_000_000,
    2014: 100_000_000,
    2015: 200_000_000,
    2016: 400_000_000,
    2017: 1_000_000_000,
    2018: 2_500_000_000,
    2019: 4_500_000_000,
    2020: 6_500_000_000,
    2021: 8_000_000_000,
    2022: 11_000_000_000,
    2023: 13_000_000_000,
    2024: 10_000_000_000,
    2025: 9_000_000_000
}

spotify_junior_h = {
    2019: 150_000_000,
    2020: 600_000_000,
    2021: 1_500_000_000,
    2022: 3_500_000_000,
    2023: 6_500_000_000,
    2024: 7_500_000_000,
    2025: 7_000_000_000
}

spotify_rauw_alejandro = {
    2016: 100_000_000,
    2017: 300_000_000,
    2018: 800_000_000,
    2019: 2_500_000_000,
    2020: 5_000_000_000,
    2021: 7_000_000_000,
    2022: 8_500_000_000,
    2023: 8_000_000_000,
    2024: 7_000_000_000,
    2025: 6_500_000_000
}

spotify_natanael_cano = {
    2018: 100_000_000,
    2019: 500_000_000,
    2020: 2_000_000_000,
    2021: 4_000_000_000,
    2022: 6_000_000_000,
    2023: 7_500_000_000,
    2024: 7_000_000_000,
    2025: 6_500_000_000
}

spotify_fuerza_regida = {
    2018: 50_000_000,
    2019: 200_000_000,
    2020: 700_000_000,
    2021: 2_000_000_000,
    2022: 4_500_000_000,
    2023: 8_500_000_000,
    2024: 8_000_000_000,
    2025: 7_500_000_000
}

spotify_myke_towers = {
    2016: 100_000_000,
    2017: 300_000_000,
    2018: 800_000_000,
    2019: 2_500_000_000,
    2020: 5_000_000_000,
    2021: 7_000_000_000,
    2022: 8_500_000_000,
    2023: 8_000_000_000,
    2024: 7_500_000_000,
    2025: 7_000_000_000
}

spotify_anuel_aa = {
    2016: 300_000_000,
    2017: 1_000_000_000,
    2018: 4_500_000_000,
    2019: 7_000_000_000,
    2020: 9_000_000_000,
    2021: 8_500_000_000,
    2022: 8_000_000_000,
    2023: 7_000_000_000,
    2024: 6_500_000_000,
    2025: 6_000_000_000
}


# Creamos un diccionario en donde están los diez diccionarios de los diez artistas

artistas = {
    "Bad Bunny": spotify_bad_bunny,
    "Peso Pluma": spotify_peso_pluma,
    "Feid": spotify_feid,
    "Karol G": spotify_karol_g,
    "Junior H": spotify_junior_h,
    "Rauw Alejandro": spotify_rauw_alejandro,
    "Natanael Cano": spotify_natanael_cano,
    "Fuerza Regida": spotify_fuerza_regida,
    "Myke Towers": spotify_myke_towers,
    "Anuel AA": spotify_anuel_aa
}

# Craeamos un solo Data Frame

filas = []

for artista, datos in artistas.items():

    for anio, oyentes in datos.items():

        filas.append({
            "Artista": artista,
            "Año": anio,
            "Oyentes": oyentes
        })


df_spotify = pd.DataFrame(filas)

# Graficamos
plt.figure(figsize=(12,6))
plt.title("Reproducciones anuales en Spotify de los diez artistas latinos mas escuchados del 2024")

from matplotlib.ticker import FuncFormatter

plt.gca().yaxis.set_major_formatter(
    FuncFormatter(lambda x, p: f'{x/1e9:.1f}B')
)

barras = sns.lineplot(
    data=df_spotify,
    x="Año",
    y="Oyentes",
    hue="Artista",
    marker="o",
    markersize=9,
    linewidth=3
)
plt.xlabel("Nombre del artista")
plt.ylabel("Reproducciones estimadas en Spotify")
plt.grid(axis="y",
         linestyle="--",
         alpha=0.6)
plt.show()
